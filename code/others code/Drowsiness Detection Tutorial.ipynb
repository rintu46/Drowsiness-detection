# %% [markdown]
# # 1. Install and Import Dependencies

# %%
# !pip install torch==1.8.1+cu111 torchvision==0.9.1+cu111 torchaudio===0.8.1 -f https://download.pytorch.org/whl/lts/1.8/torch_lts.html
# Out:
# Looking in links: https://download.pytorch.org/whl/lts/1.8/torch_lts.html
# Requirement already satisfied: torch==1.8.1+cu111 in d:\yolo\flaskenv\lib\site-packages (1.8.1+cu111)
# Requirement already satisfied: torchvision==0.9.1+cu111 in d:\yolo\flaskenv\lib\site-packages (0.9.1+cu111)
# Requirement already satisfied: torchaudio===0.8.1 in d:\yolo\flaskenv\lib\site-packages (0.8.1)
# Requirement already satisfied: numpy in d:\yolo\flaskenv\lib\site-packages (from torch==1.8.1+cu111) (1.22.3)
# Requirement already satisfied: typing-extensions in d:\yolo\flaskenv\lib\site-packages (from torch==1.8.1+cu111) (4.1.1)
# Requirement already satisfied: pillow>=4.1.1 in d:\yolo\flaskenv\lib\site-packages (from torchvision==0.9.1+cu111) (9.1.0)

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# !cd yolov5 & pip install -r requirements.txt
# Out:
# Requirement already satisfied: matplotlib>=3.2.2 in d:\yolo\flaskenv\lib\site-packages (from -r requirements.txt (line 4)) (3.5.1)
# Requirement already satisfied: numpy>=1.18.5 in d:\yolo\flaskenv\lib\site-packages (from -r requirements.txt (line 5)) (1.22.3)
# Requirement already satisfied: opencv-python>=4.1.2 in d:\yolo\flaskenv\lib\site-packages (from -r requirements.txt (line 6)) (4.5.5.64)
# Requirement already satisfied: Pillow>=7.1.2 in d:\yolo\flaskenv\lib\site-packages (from -r requirements.txt (line 7)) (9.1.0)
# Requirement already satisfied: PyYAML>=5.3.1 in d:\yolo\flaskenv\lib\site-packages (from -r requirements.txt (line 8)) (6.0)
# Requirement already satisfied: requests>=2.23.0 in d:\yolo\flaskenv\lib\site-packages (from -r requirements.txt (line 9)) (2.27.1)
# Requirement already satisfied: scipy>=1.4.1 in d:\yolo\flaskenv\lib\site-packages (from -r requirements.txt (line 10)) (1.8.0)
# Requirement already satisfied: torch>=1.7.0 in d:\yolo\flaskenv\lib\site-packages (from -r requirements.txt (line 11)) (1.8.1+cu111)
# Requirement already satisfied: torchvision>=0.8.1 in d:\yolo\flaskenv\lib\site-packages (from -r requirements.txt (line 12)) (0.9.1+cu111)
# Requirement already satisfied: tqdm>=4.41.0 in d:\yolo\flaskenv\lib\site-packages (from -r requirements.txt (line 13)) (4.64.0)
# Requirement already satisfied: tensorboard>=2.4.1 in d:\yolo\flaskenv\lib\site-packages (from -r requirements.txt (line 16)) (2.8.0)
# Requirement already satisfied: pandas>=1.1.4 in d:\yolo\flaskenv\lib\site-packages (from -r requirements.txt (line 20)) (1.4.2)
# Requirement already satisfied: seaborn>=0.11.0 in d:\yolo\flaskenv\lib\site-packages (from -r requirements.txt (line 21)) (0.11.2)
# Requirement already satisfied: thop in d:\yolo\flaskenv\lib\site-packages (from -r requirements.txt (line 37)) (0.0.31.post2005241907)
# Requirement already satisfied: fonttools>=4.22.0 in d:\yolo\flaskenv\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (4.31.2)
# Requirement already satisfied: cycler>=0.10 in d:\yolo\flaskenv\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\yolo\flaskenv\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (3.0.7)
# Requirement already satisfied: packaging>=20.0 in d:\yolo\flaskenv\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in d:\yolo\flaskenv\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\yolo\flaskenv\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (1.4.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\yolo\flaskenv\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\yolo\flaskenv\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in d:\yolo\flaskenv\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\yolo\flaskenv\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (2021.10.8)
# Requirement already satisfied: typing-extensions in d:\yolo\flaskenv\lib\site-packages (from torch>=1.7.0->-r requirements.txt (line 11)) (4.1.1)
# Requirement already satisfied: colorama in d:\yolo\flaskenv\lib\site-packages (from tqdm>=4.41.0->-r requirements.txt (line 13)) (0.4.4)
# Requirement already satisfied: setuptools>=41.0.0 in d:\yolo\flaskenv\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (61.0.0)
# Requirement already satisfied: grpcio>=1.24.3 in d:\yolo\flaskenv\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (1.44.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in d:\yolo\flaskenv\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (2.6.2)
# Requirement already satisfied: protobuf>=3.6.0 in d:\yolo\flaskenv\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (3.20.0)
# Requirement already satisfied: wheel>=0.26 in d:\yolo\flaskenv\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (0.37.1)
# Requirement already satisfied: werkzeug>=0.11.15 in d:\yolo\flaskenv\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (2.1.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in d:\yolo\flaskenv\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in d:\yolo\flaskenv\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (3.3.6)
# Requirement already satisfied: absl-py>=0.4 in d:\yolo\flaskenv\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (1.0.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in d:\yolo\flaskenv\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in d:\yolo\flaskenv\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (0.6.1)
# Requirement already satisfied: pytz>=2020.1 in d:\yolo\flaskenv\lib\site-packages (from pandas>=1.1.4->-r requirements.txt (line 20)) (2022.1)
# Requirement already satisfied: six in d:\yolo\flaskenv\lib\site-packages (from absl-py>=0.4->tensorboard>=2.4.1->-r requirements.txt (line 16)) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\yolo\flaskenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 16)) (4.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\yolo\flaskenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 16)) (5.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\yolo\flaskenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 16)) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\yolo\flaskenv\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.4.1->-r requirements.txt (line 16)) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in d:\yolo\flaskenv\lib\site-packages (from markdown>=2.6.8->tensorboard>=2.4.1->-r requirements.txt (line 16)) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in d:\yolo\flaskenv\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.4.1->-r requirements.txt (line 16)) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\yolo\flaskenv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 16)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\yolo\flaskenv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.4.1->-r requirements.txt (line 16)) (3.2.0)

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %% [markdown]
# # 2. Load Model

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in C:\Users\User/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2022-4-6 torch 1.8.1+cu111 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8192MiB)
#
# Fusing layers...
# YOLOv5s_v6 summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): Model(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (3): Conv(
#           (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (4): C3(
#           (cv1): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (5): Conv(
#           (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (6): C3(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (7): Conv(
#           (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (8): C3(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (9): SPPF(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#         )
#         (10): Conv(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (11): Upsample(scale_factor=2.0, mode=nearest)
#         (12): Concat()
#         (13): C3(
#           (cv1): Conv(
#             (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (14): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (15): Upsample(scale_factor=2.0, mode=nearest)
#         (16): Concat()
#         (17): C3(
#           (cv1): Conv(
#             (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (18): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (19): Concat()
#         (20): C3(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (21): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (22): Concat()
#         (23): C3(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (24): Detect(
#           (m): ModuleList(
#             (0): Conv2d(128, 255, kernel_size=(1, 1), stride=(1, 1))
#             (1): Conv2d(256, 255, kernel_size=(1, 1), stride=(1, 1))
#             (2): Conv2d(512, 255, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#       )
#     )
#   )
# )

# %% [markdown]
# # 3. Make Detections with Images

# %%
img = 'https://upload.wikimedia.org/wikipedia/commons/thumb/e/e4/Cars_in_traffic_in_Auckland%2C_New_Zealand_-_copyright-free_photo_released_to_public_domain.jpg/800px-Cars_in_traffic_in_Auckland%2C_New_Zealand_-_copyright-free_photo_released_to_public_domain.jpg'

# %%
img = 'C:/Users/User/c3.jpg'

# %%
results = model(img)
results.print()
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11992/3432295373.py in <module>
# ----> 1 results = model(img)
#       2 results.print()
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~\anaconda3\lib\site-packages\torch\autograd\grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.__class__():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# ~/.cache\torch\hub\ultralytics_yolov5_master\models\common.py in forward(self, imgs, size, augment, profile)
#     541             f = f'image{i}'  # filename
#     542             if isinstance(im, (str, Path)):  # filename or uri
# --> 543                 im, f = Image.open(requests.get(im, stream=True).raw if str(im).startswith('http') else im), im
#     544                 im = np.asarray(exif_transpose(im))
#     545             elif isinstance(im, Image.Image):  # PIL Image
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    3028     for message in accept_warnings:
#    3029         warnings.warn(message)
# -> 3030     raise UnidentifiedImageError(
#    3031         "cannot identify image file %r" % (filename if filename else fp)
#    3032     )
#
# UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x000001C3A8ACE720>

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
results.render()
# Out:
# [array([[[251, 216, 174],
#          [254, 219, 177],
#          [246, 213, 168],
#          ...,
#          [128, 148, 146],
#          [ 70,  79,  52],
#          [ 64,  71,  29]],
#
#         [[235, 201, 156],
#          [234, 200, 155],
#          [221, 189, 142],
#          ...,
#          [122, 141, 139],
#          [ 85,  91,  65],
#          [ 47,  52,  11]],
#
#         [[253, 219, 171],
#          [245, 213, 164],
#          [212, 180, 131],
#          ...,
#          [136, 155, 153],
#          [ 69,  73,  46],
#          [ 60,  62,  22]],
#
#         ...,
#
#         [[ 61,  69,  80],
#          [ 64,  72,  83],
#          [ 61,  69,  80],
#          ...,
#          [ 47,  52,  56],
#          [ 48,  53,  57],
#          [ 49,  54,  58]],
#
#         [[ 56,  64,  75],
#          [ 72,  80,  91],
#          [ 70,  78,  89],
#          ...,
#          [ 48,  53,  57],
#          [ 48,  53,  57],
#          [ 50,  55,  59]],
#
#         [[ 64,  72,  83],
#          [ 76,  84,  95],
#          [ 63,  71,  82],
#          ...,
#          [ 49,  54,  58],
#          [ 49,  54,  58],
#          [ 50,  55,  59]]], dtype=uint8)]

# %% [markdown]
# # 4. Real Time Detections

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 5. Train from scratch

# %%
import uuid   # Unique identifier
import os
import time

# %%
IMAGES_PATH = os.path.join('data', 'images') #/data/images
labels = ['awake', 'drowsy']
number_imgs = 5

# %%
cap = cv2.VideoCapture(0)
# Loop through labels
for label in labels:
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    
    # Loop through image range
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        
        # Webcam feed
        ret, frame = cap.read()
        
        # Naming out image path
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        
        # Writes out image to file 
#         cv2.imwrite(imgname, frame)
        
        # Render to the screen
#         cv2.imshow('Image Collection', frame)
        
        # 2 second delay between captures
#         time.sleep(2)
        
#         if cv2.waitKey(10) & 0xFF == ord('q'):
#             break
# cap.release()
# cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8428/3396655558.py in <module>
# ----> 1 cap = cv2.VideoCapture(0)
#       2 # Loop through labels
#       3 for label in labels:
#       4     print('Collecting images for {}'.format(label))
#       5     time.sleep(5)
#
# NameError: name 'cv2' is not defined

# %%
print(os.path.join(IMAGES_PATH, labels[0]+'.'+str(uuid.uuid1())+'.jpg'))
# Out:
# data\images\awake.da2d648b-b649-11ec-abe8-1c99571bee10.jpg

# %%
for label in labels:
    print('Collecting images for {}'.format(label))
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        print(imgname)
# Out:
# Collecting images for awake
# Collecting images for awake, image number 0
# data\images\awake.dab08499-b649-11ec-ac98-1c99571bee10.jpg
# Collecting images for awake, image number 1
# data\images\awake.dab0849a-b649-11ec-bf90-1c99571bee10.jpg
# Collecting images for awake, image number 2
# data\images\awake.dab0849b-b649-11ec-888e-1c99571bee10.jpg
# Collecting images for awake, image number 3
# data\images\awake.dab0849c-b649-11ec-9b12-1c99571bee10.jpg
# Collecting images for awake, image number 4
# data\images\awake.dab0ab90-b649-11ec-9612-1c99571bee10.jpg
# Collecting images for drowsy
# Collecting images for drowsy, image number 0
# data\images\drowsy.dab0ab91-b649-11ec-a9a6-1c99571bee10.jpg
# Collecting images for drowsy, image number 1
# data\images\drowsy.dab0ab92-b649-11ec-a57b-1c99571bee10.jpg
# Collecting images for drowsy, image number 2
# data\images\drowsy.dab0ab93-b649-11ec-a203-1c99571bee10.jpg
# Collecting images for drowsy, image number 3
# data\images\drowsy.dab0ab94-b649-11ec-a448-1c99571bee10.jpg
# Collecting images for drowsy, image number 4
# data\images\drowsy.dab0ab95-b649-11ec-99c2-1c99571bee10.jpg

# %%
# !git clone https://github.com/tzutalin/labelImg
# Out:
# fatal: destination path 'labelImg' already exists and is not an empty directory.

# %%
# !pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc
# Out:
# Requirement already satisfied: pyqt5 in d:\yolo\flaskenv\lib\site-packages (5.15.6)
# Requirement already satisfied: lxml in d:\yolo\flaskenv\lib\site-packages (4.8.0)
# Requirement already satisfied: PyQt5-Qt5>=5.15.2 in d:\yolo\flaskenv\lib\site-packages (from pyqt5) (5.15.2)
# Requirement already satisfied: PyQt5-sip<13,>=12.8 in d:\yolo\flaskenv\lib\site-packages (from pyqt5) (12.9.1)

# %%
cd yolov5 -- python train.py
# Out:
# [WinError 2] The system cannot find the file specified: 'yolov5 -- python train.py'
# C:\Users\User\Desktop\test 2\YOLO-Drowsiness-Detection-main\yolov5

# %%
# !cd yolov5 --data dataset.yml
# Out:
# The system cannot find the path specified.

# %%
# !cd yolov5 && python train.py
# Out:
# train: weights=yolov5s.pt, cfg=, data=data\coco128.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=300, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# From https://github.com/ultralytics/yolov5
#    19cc7c6..1a24716  update/restapi -> origin/update/restapi
# github:  YOLOv5 is out of date by 8 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# fatal: cannot change to 'C:\Users\User\Desktop\test': No such file or directory
# YOLOv5  2022-4-5 torch 1.8.1+cu111 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8192MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5  runs (RECOMMENDED)
# TensorBoard: Start with 'tensorboard --logdir runs\train', view at http://localhost:6006/
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorboard\compat\__init__.py", line 42, in tf
#     from tensorboard.compat import notf  # noqa: F401
# ImportError: cannot import name 'notf' from 'tensorboard.compat' (C:\Users\User\anaconda3\lib\site-packages\tensorboard\compat\__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\test 2\YOLO-Drowsiness-Detection-main\yolov5\train.py", line 662, in <module>
#     main(opt)
#   File "C:\Users\User\Desktop\test 2\YOLO-Drowsiness-Detection-main\yolov5\train.py", line 557, in main
#     train(opt.hyp, opt, device, callbacks)
#   File "C:\Users\User\Desktop\test 2\YOLO-Drowsiness-Detection-main\yolov5\train.py", line 91, in train
#     loggers = Loggers(save_dir, weights, opt, hyp, LOGGER)  # loggers instance
#   File "C:\Users\User\Desktop\test 2\YOLO-Drowsiness-Detection-main\yolov5\utils\loggers\__init__.py", line 76, in __init__
#     self.tb = SummaryWriter(str(s))
#   File "C:\Users\User\anaconda3\lib\site-packages\torch\utils\tensorboard\writer.py", line 220, in __init__
#     self._get_file_writer()
#   File "C:\Users\User\anaconda3\lib\site-packages\torch\utils\tensorboard\writer.py", line 250, in _get_file_writer
#     self.file_writer = FileWriter(self.log_dir, self.max_queue,
#   File "C:\Users\User\anaconda3\lib\site-packages\torch\utils\tensorboard\writer.py", line 60, in __init__
#     self.event_writer = EventFileWriter(
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorboard\summary\writer\event_file_writer.py", line 72, in __init__
#     tf.io.gfile.makedirs(logdir)
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorboard\lazy.py", line 65, in __getattr__
#     return getattr(load_once(self), attr_name)
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorboard\lazy.py", line 97, in wrapper
#     cache[arg] = f(arg)
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorboard\lazy.py", line 50, in load_once
#     module = load_fn()
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorboard\compat\__init__.py", line 45, in tf
#     import tensorflow
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\__init__.py", line 37, in <module>
#     from tensorflow.python.tools import module_util as _module_util
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\__init__.py", line 45, in <module>
#     from tensorflow.python.feature_column import feature_column_lib as feature_column
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\feature_column\feature_column_lib.py", line 18, in <module>
#     from tensorflow.python.feature_column.feature_column import *
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\feature_column\feature_column.py", line 143, in <module>
#     from tensorflow.python.layers import base
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\layers\base.py", line 16, in <module>
#     from tensorflow.python.keras.legacy_tf_layers import base
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\keras\__init__.py", line 25, in <module>
#     from tensorflow.python.keras import models
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\keras\models\__init__.py", line 21, in <module>
#     from tensorflow.python.keras._impl.keras.models import load_model
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\keras\_impl\keras\__init__.py", line 21, in <module>
#     from tensorflow.python.keras._impl.keras import activations
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\keras\_impl\keras\activations.py", line 24, in <module>
#     from tensorflow.python.keras._impl.keras.utils.generic_utils import deserialize_keras_object
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\keras\_impl\keras\utils\__init__.py", line 34, in <module>
#     from tensorflow.python.keras._impl.keras.utils.multi_gpu_utils import multi_gpu_model
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\keras\_impl\keras\utils\multi_gpu_utils.py", line 22, in <module>
#     from tensorflow.python.keras._impl.keras.engine.training import Model
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\keras\_impl\keras\engine\__init__.py", line 21, in <module>
#     from tensorflow.python.keras._impl.keras.engine.base_layer import InputSpec
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\keras\_impl\keras\engine\base_layer.py", line 41, in <module>
#     InputSpec = tf_base_layers.InputSpec
# AttributeError: partially initialized module 'tensorflow.python.layers.base' has no attribute 'InputSpec' (most likely due to a circular import)

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 500 --data dataset.yml --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset.yml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=5, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github:  YOLOv5 is out of date by 13 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5  v6.1-97-g2da6866 torch 1.8.1+cu111 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8192MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5  runs (RECOMMENDED)
# TensorBoard: Start with 'tensorboard --logdir runs\train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=17
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     59334  models.yolo.Detect                      [17, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 270 layers, 7065478 parameters, 7065478 gradients, 16.0 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# Scaled weight_decay = 0.0005
# optimizer: SGD with parameter groups 57 weight (no decay), 60 weight, 60 bias
#
# train: Scanning 'D:\yolo\data\labels' images and labels...:   0%|          | 0/20 [00:00<?, ?it/s]
# train: Scanning 'D:\yolo\data\labels' images and labels...1 found, 0 missing, 0 empty, 0 corrupt:   5%|5         | 1/20 [00:01<00:34,  1.82s/it]
# train: Scanning 'D:\yolo\data\labels' images and labels...2 found, 0 missing, 0 empty, 0 corrupt:  10%|#         | 2/20 [00:01<00:14,  1.21it/s]
# train: Scanning 'D:\yolo\data\labels' images and labels...20 found, 0 missing, 0 empty, 0 corrupt: 100%|##########| 20/20 [00:01<00:00, 10.16it/s]
# train: New cache created: D:\yolo\data\labels.cache
#
# val: Scanning 'D:\yolo\data\labels.cache' images and labels... 20 found, 0 missing, 0 empty, 0 corrupt: 100%|##########| 20/20 [00:00<?, ?it/s]
# val: Scanning 'D:\yolo\data\labels.cache' images and labels... 20 found, 0 missing, 0 empty, 0 corrupt: 100%|##########| 20/20 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 125, in _main
#     prepare(preparation_data)
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 236, in prepare
#     _fixup_main_from_path(data['init_main_from_path'])
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 287, in _fixup_main_from_path
#     main_content = runpy.run_path(main_path,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 268, in run_path
#     return _run_module_code(code, init_globals, run_name,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 97, in _run_module_code
#     _run_code(code, mod_globals, init_globals,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "D:\yolo\yolov5\train.py", line 26, in <module>
#     import torch
#   File "D:\yolo\flaskenv\lib\site-packages\torch\__init__.py", line 123, in <module>
#     raise err
# OSError: [WinError 1455] The paging file is too small for this operation to complete. Error loading "D:\yolo\flaskenv\lib\site-packages\torch\lib\cudnn_cnn_infer64_8.dll" or one of its dependencies.
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 125, in _main
#     prepare(preparation_data)
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 236, in prepare
#     _fixup_main_from_path(data['init_main_from_path'])
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 287, in _fixup_main_from_path
#     main_content = runpy.run_path(main_path,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 268, in run_path
#     return _run_module_code(code, init_globals, run_name,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 97, in _run_module_code
#     _run_code(code, mod_globals, init_globals,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "D:\yolo\yolov5\train.py", line 26, in <module>
#     import torch
#   File "D:\yolo\flaskenv\lib\site-packages\torch\__init__.py", line 123, in <module>
#     raise err
# OSError: [WinError 1455] The paging file is too small for this operation to complete. Error loading "D:\yolo\flaskenv\lib\site-packages\torch\lib\cudnn_adv_infer64_8.dll" or one of its dependencies.
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 125, in _main
#     prepare(preparation_data)
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 236, in prepare
#     _fixup_main_from_path(data['init_main_from_path'])
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 287, in _fixup_main_from_path
#     main_content = runpy.run_path(main_path,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 268, in run_path
#     return _run_module_code(code, init_globals, run_name,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 97, in _run_module_code
#     _run_code(code, mod_globals, init_globals,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "D:\yolo\yolov5\train.py", line 26, in <module>
#     import torch
#   File "D:\yolo\flaskenv\lib\site-packages\torch\__init__.py", line 123, in <module>
#     raise err
# OSError: [WinError 1455] The paging file is too small for this operation to complete. Error loading "D:\yolo\flaskenv\lib\site-packages\torch\lib\caffe2_detectron_ops_gpu.dll" or one of its dependencies.
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 125, in _main
#     prepare(preparation_data)
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 236, in prepare
#     _fixup_main_from_path(data['init_main_from_path'])
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 287, in _fixup_main_from_path
#     main_content = runpy.run_path(main_path,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 268, in run_path
#     return _run_module_code(code, init_globals, run_name,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 97, in _run_module_code
#     _run_code(code, mod_globals, init_globals,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "D:\yolo\yolov5\train.py", line 26, in <module>
#     import torch
#   File "D:\yolo\flaskenv\lib\site-packages\torch\__init__.py", line 123, in <module>
#     raise err
# OSError: [WinError 1455] The paging file is too small for this operation to complete. Error loading "D:\yolo\flaskenv\lib\site-packages\torch\lib\caffe2_detectron_ops_gpu.dll" or one of its dependencies.
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 125, in _main
#     prepare(preparation_data)
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 236, in prepare
#     _fixup_main_from_path(data['init_main_from_path'])
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 287, in _fixup_main_from_path
#     main_content = runpy.run_path(main_path,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 268, in run_path
#     return _run_module_code(code, init_globals, run_name,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 97, in _run_module_code
#     _run_code(code, mod_globals, init_globals,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "D:\yolo\yolov5\train.py", line 26, in <module>
#     import torch
#   File "D:\yolo\flaskenv\lib\site-packages\torch\__init__.py", line 123, in <module>
#     raise err
# OSError: [WinError 1455] The paging file is too small for this operation to complete. Error loading "D:\yolo\flaskenv\lib\site-packages\torch\lib\caffe2_detectron_ops_gpu.dll" or one of its dependencies.
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 125, in _main
#     prepare(preparation_data)
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 236, in prepare
#     _fixup_main_from_path(data['init_main_from_path'])
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 287, in _fixup_main_from_path
#     main_content = runpy.run_path(main_path,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 268, in run_path
#     return _run_module_code(code, init_globals, run_name,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 97, in _run_module_code
#     _run_code(code, mod_globals, init_globals,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "D:\yolo\yolov5\train.py", line 26, in <module>
#     import torch
#   File "D:\yolo\flaskenv\lib\site-packages\torch\__init__.py", line 123, in <module>
#     raise err
# OSError: [WinError 1455] The paging file is too small for this operation to complete. Error loading "D:\yolo\flaskenv\lib\site-packages\torch\lib\cudnn_cnn_infer64_8.dll" or one of its dependencies.
# Plotting labels to runs\train\exp16\labels.jpg...
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 125, in _main
#     prepare(preparation_data)
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 236, in prepare
#     _fixup_main_from_path(data['init_main_from_path'])
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 287, in _fixup_main_from_path
#     main_content = runpy.run_path(main_path,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 268, in run_path
#     return _run_module_code(code, init_globals, run_name,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 97, in _run_module_code
#     _run_code(code, mod_globals, init_globals,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "D:\yolo\yolov5\train.py", line 41, in <module>
#     import val  # for end-of-epoch mAP
#   File "D:\yolo\yolov5\val.py", line 38, in <module>
#     from models.common import DetectMultiBackend
#   File "D:\yolo\yolov5\models\common.py", line 27, in <module>
#     from utils.plots import Annotator, colors, save_one_box
#   File "D:\yolo\yolov5\utils\plots.py", line 17, in <module>
#     import seaborn as sn
#   File "D:\yolo\flaskenv\lib\site-packages\seaborn\__init__.py", line 2, in <module>
#     from .rcmod import *  # noqa: F401,F403
#   File "D:\yolo\flaskenv\lib\site-packages\seaborn\rcmod.py", line 7, in <module>
#     from . import palettes
#   File "D:\yolo\flaskenv\lib\site-packages\seaborn\palettes.py", line 9, in <module>
#     from .utils import desaturate, get_color_cycle
#   File "D:\yolo\flaskenv\lib\site-packages\seaborn\utils.py", line 10, in <module>
#     from scipy import stats
#   File "D:\yolo\flaskenv\lib\site-packages\scipy\__init__.py", line 136, in <module>
#     from . import _distributor_init
#   File "D:\yolo\flaskenv\lib\site-packages\scipy\_distributor_init.py", line 64, in <module>
#     WinDLL(os.path.abspath(filename))
#   File "C:\Users\User\anaconda3\lib\ctypes\__init__.py", line 382, in __init__
#     self._handle = _dlopen(self._name, mode)
# OSError: [WinError 1455] The paging file is too small for this operation to complete
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 125, in _main
#     prepare(preparation_data)
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 236, in prepare
#     _fixup_main_from_path(data['init_main_from_path'])
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 287, in _fixup_main_from_path
#     main_content = runpy.run_path(main_path,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 268, in run_path
#     return _run_module_code(code, init_globals, run_name,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 97, in _run_module_code
#     _run_code(code, mod_globals, init_globals,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "D:\yolo\yolov5\train.py", line 41, in <module>
#     import val  # for end-of-epoch mAP
#   File "D:\yolo\yolov5\val.py", line 38, in <module>
#     from models.common import DetectMultiBackend
#   File "D:\yolo\yolov5\models\common.py", line 27, in <module>
#     from utils.plots import Annotator, colors, save_one_box
#   File "D:\yolo\yolov5\utils\plots.py", line 17, in <module>
#     import seaborn as sn
#   File "D:\yolo\flaskenv\lib\site-packages\seaborn\__init__.py", line 2, in <module>
#     from .rcmod import *  # noqa: F401,F403
#   File "D:\yolo\flaskenv\lib\site-packages\seaborn\rcmod.py", line 7, in <module>
#     from . import palettes
#   File "D:\yolo\flaskenv\lib\site-packages\seaborn\palettes.py", line 9, in <module>
#     from .utils import desaturate, get_color_cycle
#   File "D:\yolo\flaskenv\lib\site-packages\seaborn\utils.py", line 10, in <module>
#     from scipy import stats
#   File "D:\yolo\flaskenv\lib\site-packages\scipy\__init__.py", line 136, in <module>
#     from . import _distributor_init
#   File "D:\yolo\flaskenv\lib\site-packages\scipy\_distributor_init.py", line 64, in <module>
#     WinDLL(os.path.abspath(filename))
#   File "C:\Users\User\anaconda3\lib\ctypes\__init__.py", line 382, in __init__
#     self._handle = _dlopen(self._name, mode)
# OSError: [WinError 1455] The paging file is too small for this operation to complete
# THCudaCheck FAIL file=..\aten\src\THC\THCCachingHostAllocator.cpp line=278 error=2 : out of memory
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 125, in _main
#     prepare(preparation_data)
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 236, in prepare
#     _fixup_main_from_path(data['init_main_from_path'])
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 287, in _fixup_main_from_path
#     main_content = runpy.run_path(main_path,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 268, in run_path
#     return _run_module_code(code, init_globals, run_name,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 97, in _run_module_code
#     _run_code(code, mod_globals, init_globals,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "D:\yolo\yolov5\train.py", line 41, in <module>
#     import val  # for end-of-epoch mAP
#   File "D:\yolo\yolov5\val.py", line 38, in <module>
#     from models.common import DetectMultiBackend
#   File "D:\yolo\yolov5\models\common.py", line 27, in <module>
#     from utils.plots import Annotator, colors, save_one_box
#   File "D:\yolo\yolov5\utils\plots.py", line 17, in <module>
#     import seaborn as sn
#   File "D:\yolo\flaskenv\lib\site-packages\seaborn\__init__.py", line 2, in <module>
#     from .rcmod import *  # noqa: F401,F403
#   File "D:\yolo\flaskenv\lib\site-packages\seaborn\rcmod.py", line 7, in <module>
#     from . import palettes
#   File "D:\yolo\flaskenv\lib\site-packages\seaborn\palettes.py", line 9, in <module>
#     from .utils import desaturate, get_color_cycle
#   File "D:\yolo\flaskenv\lib\site-packages\seaborn\utils.py", line 10, in <module>
#     from scipy import stats
#   File "D:\yolo\flaskenv\lib\site-packages\scipy\stats\__init__.py", line 461, in <module>
#     from . import qmc
#   File "D:\yolo\flaskenv\lib\site-packages\scipy\stats\qmc.py", line 234, in <module>
#     from ._qmc import *
#   File "D:\yolo\flaskenv\lib\site-packages\scipy\stats\_qmc.py", line 31, in <module>
#     from scipy.stats._sobol import (
# ImportError: DLL load failed while importing _sobol: The paging file is too small for this operation to complete.
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 125, in _main
#     prepare(preparation_data)
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 236, in prepare
#     _fixup_main_from_path(data['init_main_from_path'])
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 287, in _fixup_main_from_path
#     main_content = runpy.run_path(main_path,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 268, in run_path
#     return _run_module_code(code, init_globals, run_name,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 97, in _run_module_code
#     _run_code(code, mod_globals, init_globals,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "D:\yolo\yolov5\train.py", line 41, in <module>
#     import val  # for end-of-epoch mAP
#   File "D:\yolo\yolov5\val.py", line 38, in <module>
#     from models.common import DetectMultiBackend
#   File "D:\yolo\yolov5\models\common.py", line 27, in <module>
#     from utils.plots import Annotator, colors, save_one_box
#   File "D:\yolo\yolov5\utils\plots.py", line 17, in <module>
#     import seaborn as sn
#   File "D:\yolo\flaskenv\lib\site-packages\seaborn\__init__.py", line 2, in <module>
#     from .rcmod import *  # noqa: F401,F403
#   File "D:\yolo\flaskenv\lib\site-packages\seaborn\rcmod.py", line 7, in <module>
#     from . import palettes
#   File "D:\yolo\flaskenv\lib\site-packages\seaborn\palettes.py", line 9, in <module>
#     from .utils import desaturate, get_color_cycle
#   File "D:\yolo\flaskenv\lib\site-packages\seaborn\utils.py", line 10, in <module>
#     from scipy import stats
#   File "D:\yolo\flaskenv\lib\site-packages\scipy\stats\__init__.py", line 461, in <module>
#     from . import qmc
#   File "D:\yolo\flaskenv\lib\site-packages\scipy\stats\qmc.py", line 234, in <module>
#     from ._qmc import *
#   File "D:\yolo\flaskenv\lib\site-packages\scipy\stats\_qmc.py", line 31, in <module>
#     from scipy.stats._sobol import (
# ImportError: DLL load failed while importing _sobol: The paging file is too small for this operation to complete.
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 125, in _main
#     prepare(preparation_data)
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 236, in prepare
#     _fixup_main_from_path(data['init_main_from_path'])
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 287, in _fixup_main_from_path
#     main_content = runpy.run_path(main_path,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 268, in run_path
#     return _run_module_code(code, init_globals, run_name,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 97, in _run_module_code
#     _run_code(code, mod_globals, init_globals,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "D:\yolo\yolov5\train.py", line 41, in <module>
#     import val  # for end-of-epoch mAP
#   File "D:\yolo\yolov5\val.py", line 38, in <module>
#     from models.common import DetectMultiBackend
#   File "D:\yolo\yolov5\models\common.py", line 27, in <module>
#     from utils.plots import Annotator, colors, save_one_box
#   File "D:\yolo\yolov5\utils\plots.py", line 17, in <module>
#     import seaborn as sn
#   File "D:\yolo\flaskenv\lib\site-packages\seaborn\__init__.py", line 2, in <module>
#     from .rcmod import *  # noqa: F401,F403
#   File "D:\yolo\flaskenv\lib\site-packages\seaborn\rcmod.py", line 7, in <module>
#     from . import palettes
#   File "D:\yolo\flaskenv\lib\site-packages\seaborn\palettes.py", line 9, in <module>
#     from .utils import desaturate, get_color_cycle
#   File "D:\yolo\flaskenv\lib\site-packages\seaborn\utils.py", line 10, in <module>
#     from scipy import stats
#   File "D:\yolo\flaskenv\lib\site-packages\scipy\stats\__init__.py", line 453, in <module>
#     from ._stats_py import *
#   File "D:\yolo\flaskenv\lib\site-packages\scipy\stats\_stats_py.py", line 44, in <module>
#     from . import distributions
#   File "D:\yolo\flaskenv\lib\site-packages\scipy\stats\distributions.py", line 8, in <module>
#     from ._distn_infrastructure import (rv_discrete, rv_continuous, rv_frozen)
#   File "D:\yolo\flaskenv\lib\site-packages\scipy\stats\_distn_infrastructure.py", line 24, in <module>
#     from scipy import optimize
#   File "D:\yolo\flaskenv\lib\site-packages\scipy\optimize\__init__.py", line 412, in <module>
#     from ._linprog import linprog, linprog_verbose_callback
#   File "D:\yolo\flaskenv\lib\site-packages\scipy\optimize\_linprog.py", line 23, in <module>
#     from ._linprog_ip import _linprog_ip
#   File "D:\yolo\flaskenv\lib\site-packages\scipy\optimize\_linprog_ip.py", line 27, in <module>
#     from ._linprog_util import _postsolve
#   File "D:\yolo\flaskenv\lib\site-packages\scipy\optimize\_linprog_util.py", line 9, in <module>
#     from scipy.optimize._remove_redundancy import (
#   File "D:\yolo\flaskenv\lib\site-packages\scipy\optimize\_remove_redundancy.py", line 9, in <module>
#     from scipy.linalg.interpolative import interp_decomp
#   File "D:\yolo\flaskenv\lib\site-packages\scipy\linalg\interpolative.py", line 385, in <module>
#     import scipy.linalg._interpolative_backend as _backend
#   File "D:\yolo\flaskenv\lib\site-packages\scipy\linalg\_interpolative_backend.py", line 34, in <module>
#     import scipy.linalg._interpolative as _id
# ImportError: DLL load failed while importing _interpolative: The paging file is too small for this operation to complete.
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 125, in _main
#     prepare(preparation_data)
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 236, in prepare
#     _fixup_main_from_path(data['init_main_from_path'])
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 287, in _fixup_main_from_path
#     main_content = runpy.run_path(main_path,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 268, in run_path
#     return _run_module_code(code, init_globals, run_name,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 97, in _run_module_code
#     _run_code(code, mod_globals, init_globals,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "D:\yolo\yolov5\train.py", line 41, in <module>
#     import val  # for end-of-epoch mAP
#   File "D:\yolo\yolov5\val.py", line 38, in <module>
#     from models.common import DetectMultiBackend
#   File "D:\yolo\yolov5\models\common.py", line 27, in <module>
#     from utils.plots import Annotator, colors, save_one_box
#   File "D:\yolo\yolov5\utils\plots.py", line 17, in <module>
#     import seaborn as sn
#   File "D:\yolo\flaskenv\lib\site-packages\seaborn\__init__.py", line 2, in <module>
#     from .rcmod import *  # noqa: F401,F403
#   File "D:\yolo\flaskenv\lib\site-packages\seaborn\rcmod.py", line 7, in <module>
#     from . import palettes
#   File "D:\yolo\flaskenv\lib\site-packages\seaborn\palettes.py", line 9, in <module>
#     from .utils import desaturate, get_color_cycle
#   File "D:\yolo\flaskenv\lib\site-packages\seaborn\utils.py", line 10, in <module>
#     from scipy import stats
#   File "D:\yolo\flaskenv\lib\site-packages\scipy\__init__.py", line 136, in <module>
#     from . import _distributor_init
#   File "D:\yolo\flaskenv\lib\site-packages\scipy\_distributor_init.py", line 64, in <module>
#     WinDLL(os.path.abspath(filename))
#   File "C:\Users\User\anaconda3\lib\ctypes\__init__.py", line 382, in __init__
#     self._handle = _dlopen(self._name, mode)
# OSError: [WinError 1455] The paging file is too small for this operation to complete
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 125, in _main
#     prepare(preparation_data)
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 236, in prepare
#     _fixup_main_from_path(data['init_main_from_path'])
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 287, in _fixup_main_from_path
#     main_content = runpy.run_path(main_path,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 268, in run_path
#     return _run_module_code(code, init_globals, run_name,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 97, in _run_module_code
#     _run_code(code, mod_globals, init_globals,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "D:\yolo\yolov5\train.py", line 41, in <module>
#     import val  # for end-of-epoch mAP
#   File "D:\yolo\yolov5\val.py", line 38, in <module>
#     from models.common import DetectMultiBackend
#   File "D:\yolo\yolov5\models\common.py", line 27, in <module>
#     from utils.plots import Annotator, colors, save_one_box
#   File "D:\yolo\yolov5\utils\plots.py", line 17, in <module>
#     import seaborn as sn
#   File "D:\yolo\flaskenv\lib\site-packages\seaborn\__init__.py", line 2, in <module>
#     from .rcmod import *  # noqa: F401,F403
#   File "D:\yolo\flaskenv\lib\site-packages\seaborn\rcmod.py", line 7, in <module>
#     from . import palettes
#   File "D:\yolo\flaskenv\lib\site-packages\seaborn\palettes.py", line 9, in <module>
#     from .utils import desaturate, get_color_cycle
#   File "D:\yolo\flaskenv\lib\site-packages\seaborn\utils.py", line 10, in <module>
#     from scipy import stats
#   File "D:\yolo\flaskenv\lib\site-packages\scipy\stats\__init__.py", line 453, in <module>
#     from ._stats_py import *
#   File "D:\yolo\flaskenv\lib\site-packages\scipy\stats\_stats_py.py", line 44, in <module>
#     from . import distributions
#   File "D:\yolo\flaskenv\lib\site-packages\scipy\stats\distributions.py", line 8, in <module>
#     from ._distn_infrastructure import (rv_discrete, rv_continuous, rv_frozen)
#   File "D:\yolo\flaskenv\lib\site-packages\scipy\stats\_distn_infrastructure.py", line 27, in <module>
#     from scipy import integrate
#   File "D:\yolo\flaskenv\lib\site-packages\scipy\integrate\__init__.py", line 95, in <module>
#     from ._ode import *
#   File "D:\yolo\flaskenv\lib\site-packages\scipy\integrate\_ode.py", line 91, in <module>
#     from . import _dop
# ImportError: DLL load failed while importing _dop: The paging file is too small for this operation to complete.
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\multiprocessing\queues.py", line 245, in _feed
#     obj = _ForkingPickler.dumps(obj)
#   File "C:\Users\User\anaconda3\lib\multiprocessing\reduction.py", line 51, in dumps
#     cls(buf, protocol).dump(obj)
#   File "D:\yolo\flaskenv\lib\site-packages\torch\multiprocessing\reductions.py", line 312, in reduce_storage
#     metadata = storage._share_filename_()
# RuntimeError: Couldn't open shared file mapping: <000001DB38705D22>, error code: <1455>
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 125, in _main
#     prepare(preparation_data)
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 236, in prepare
#     _fixup_main_from_path(data['init_main_from_path'])
#   File "C:\Users\User\anaconda3\lib\multiprocessing\spawn.py", line 287, in _fixup_main_from_path
#     main_content = runpy.run_path(main_path,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 268, in run_path
#     return _run_module_code(code, init_globals, run_name,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 97, in _run_module_code
#     _run_code(code, mod_globals, init_globals,
#   File "C:\Users\User\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "D:\yolo\yolov5\train.py", line 41, in <module>
#     import val  # for end-of-epoch mAP
#   File "D:\yolo\yolov5\val.py", line 38, in <module>
#     from models.common import DetectMultiBackend
#   File "D:\yolo\yolov5\models\common.py", line 27, in <module>
#     from utils.plots import Annotator, colors, save_one_box
#   File "D:\yolo\yolov5\utils\plots.py", line 17, in <module>
#     import seaborn as sn
#   File "D:\yolo\flaskenv\lib\site-packages\seaborn\__init__.py", line 2, in <module>
#     from .rcmod import *  # noqa: F401,F403
#   File "D:\yolo\flaskenv\lib\site-packages\seaborn\rcmod.py", line 7, in <module>
#     from . import palettes
#   File "D:\yolo\flaskenv\lib\site-packages\seaborn\palettes.py", line 9, in <module>
#     from .utils import desaturate, get_color_cycle
#   File "D:\yolo\flaskenv\lib\site-packages\seaborn\utils.py", line 10, in <module>
#     from scipy import stats
#   File "D:\yolo\flaskenv\lib\site-packages\scipy\__init__.py", line 136, in <module>
#     from . import _distributor_init
#   File "D:\yolo\flaskenv\lib\site-packages\scipy\_distributor_init.py", line 64, in <module>
#     WinDLL(os.path.abspath(filename))
#   File "C:\Users\User\anaconda3\lib\ctypes\__init__.py", line 382, in __init__
#     self._handle = _dlopen(self._name, mode)
# OSError: [WinError 1455] The paging file is too small for this operation to complete
#
# AutoAnchor: 5.35 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset
# Image sizes 320 train, 320 val
# Using 8 dataloader workers
# Logging results to runs\train\exp16
# Starting training for 5 epochs...
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#        0/4    0.837G    0.1102   0.01467   0.07636        31       320:   0%|          | 0/2 [00:01<?, ?it/s]
#        0/4    0.837G    0.1102   0.01467   0.07636        31       320:  50%|#####     | 1/2 [00:02<00:02,  2.62s/it]
#        0/4    0.906G    0.1095    0.0159   0.07814         9       320:  50%|#####     | 1/2 [00:02<00:02,  2.62s/it]
#        0/4    0.906G    0.1095    0.0159   0.07814         9       320: 100%|##########| 2/2 [00:02<00:00,  1.36s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/1 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/1 [00:05<?, ?it/s]
# Traceback (most recent call last):
#   File "D:\yolo\flaskenv\lib\site-packages\torch\utils\data\dataloader.py", line 986, in _try_get_data
#     data = self._data_queue.get(timeout=timeout)
#   File "C:\Users\User\anaconda3\lib\queue.py", line 179, in get
#     raise Empty
# _queue.Empty
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "D:\yolo\yolov5\train.py", line 662, in <module>
#     main(opt)
#   File "D:\yolo\yolov5\train.py", line 557, in main
#     train(opt.hyp, opt, device, callbacks)
#   File "D:\yolo\yolov5\train.py", line 384, in train
#     results, maps, _ = val.run(data_dict,
#   File "D:\yolo\flaskenv\lib\site-packages\torch\autograd\grad_mode.py", line 27, in decorate_context
#     return func(*args, **kwargs)
#   File "D:\yolo\yolov5\val.py", line 188, in run
#     for batch_i, (im, targets, paths, shapes) in enumerate(pbar):
#   File "D:\yolo\flaskenv\lib\site-packages\tqdm\std.py", line 1195, in __iter__
#     for obj in iterable:
#   File "D:\yolo\yolov5\utils\datasets.py", line 159, in __iter__
#     yield next(self.iterator)
#   File "D:\yolo\flaskenv\lib\site-packages\torch\utils\data\dataloader.py", line 517, in __next__
#     data = self._next_data()
#   File "D:\yolo\flaskenv\lib\site-packages\torch\utils\data\dataloader.py", line 1182, in _next_data
#     idx, data = self._get_data()
#   File "D:\yolo\flaskenv\lib\site-packages\torch\utils\data\dataloader.py", line 1138, in _get_data
#     success, data = self._try_get_data()
#   File "D:\yolo\flaskenv\lib\site-packages\torch\utils\data\dataloader.py", line 999, in _try_get_data
#     raise RuntimeError('DataLoader worker (pid(s) {}) exited unexpectedly'.format(pids_str)) from e
# RuntimeError: DataLoader worker (pid(s) 14604, 7200, 14980, 4304, 13780, 9448, 3620, 9224, 15204, 14184, 14960, 1524) exited unexpectedly

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 500 --data dataset.yml --weights yolov5s.pt --workers 2
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset.yml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=500, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=2, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github:  YOLOv5 is out of date by 13 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5  v6.1-97-g2da6866 torch 1.8.1+cu111 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8192MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5  runs (RECOMMENDED)
# TensorBoard: Start with 'tensorboard --logdir runs\train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=17
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     59334  models.yolo.Detect                      [17, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 270 layers, 7065478 parameters, 7065478 gradients, 16.0 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# Scaled weight_decay = 0.0005
# optimizer: SGD with parameter groups 57 weight (no decay), 60 weight, 60 bias
#
# train: Scanning 'D:\yolo\data\labels.cache' images and labels... 20 found, 0 missing, 0 empty, 0 corrupt: 100%|##########| 20/20 [00:00<?, ?it/s]
# train: Scanning 'D:\yolo\data\labels.cache' images and labels... 20 found, 0 missing, 0 empty, 0 corrupt: 100%|##########| 20/20 [00:00<?, ?it/s]
#
# val: Scanning 'D:\yolo\data\labels.cache' images and labels... 20 found, 0 missing, 0 empty, 0 corrupt: 100%|##########| 20/20 [00:00<?, ?it/s]
# val: Scanning 'D:\yolo\data\labels.cache' images and labels... 20 found, 0 missing, 0 empty, 0 corrupt: 100%|##########| 20/20 [00:00<?, ?it/s]
# Plotting labels to runs\train\exp17\labels.jpg...
#
# AutoAnchor: 5.35 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset
# Image sizes 320 train, 320 val
# Using 2 dataloader workers
# Logging results to runs\train\exp17
# Starting training for 500 epochs...
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#      0/499    0.837G    0.1097   0.01471   0.07725        31       320:   0%|          | 0/2 [00:01<?, ?it/s]
#      0/499    0.837G    0.1097   0.01471   0.07725        31       320:  50%|#####     | 1/2 [00:02<00:02,  2.38s/it]
#      0/499    0.906G      0.11   0.01586   0.07886         9       320:  50%|#####     | 1/2 [00:02<00:02,  2.38s/it]
#      0/499    0.906G      0.11   0.01586   0.07886         9       320: 100%|##########| 2/2 [00:02<00:00,  1.24s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/1 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 1/1 [00:00<00:00, 12.08it/s]
#                  all         20         20    0.00378       0.15    0.00252   0.000639
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
/s]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/1 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 1/1 [00:00<00:00, 14.32it/s]
#                  all         20         20      0.999          1      0.995      0.921
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#    496/499     1.01G    0.0196  0.008083  0.002395        32       320:   0%|          | 0/2 [00:00<?, ?it/s]
#    496/499     1.01G   0.02277   0.00831  0.003598         7       320:   0%|          | 0/2 [00:00<?, ?it/s]
#    496/499     1.01G   0.02277   0.00831  0.003598         7       320: 100%|##########| 2/2 [00:00<00:00, 16.44it/s]
#    496/499     1.01G   0.02277   0.00831  0.003598         7       320: 100%|##########| 2/2 [00:00<00:00, 16.44it/s]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/1 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 1/1 [00:00<00:00, 14.13it/s]
#                  all         20         20      0.999          1      0.995      0.921
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#    497/499     1.01G   0.01704  0.007753  0.002185        35       320:   0%|          | 0/2 [00:00<?, ?it/s]
#    497/499     1.01G   0.01871  0.007993  0.003557         9       320:   0%|          | 0/2 [00:00<?, ?it/s]
#    497/499     1.01G   0.01871  0.007993  0.003557         9       320: 100%|##########| 2/2 [00:00<00:00, 15.08it/s]
#    497/499     1.01G   0.01871  0.007993  0.003557         9       320: 100%|##########| 2/2 [00:00<00:00, 15.08it/s]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/1 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 1/1 [00:00<00:00, 14.32it/s]
#                  all         20         20      0.999          1      0.995      0.929
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#    498/499     1.01G   0.01673  0.006699  0.001973        29       320:   0%|          | 0/2 [00:00<?, ?it/s]
#    498/499     1.01G   0.01789  0.006747  0.002089         9       320:   0%|          | 0/2 [00:00<?, ?it/s]
#    498/499     1.01G   0.01789  0.006747  0.002089         9       320: 100%|##########| 2/2 [00:00<00:00, 16.30it/s]
#    498/499     1.01G   0.01789  0.006747  0.002089         9       320: 100%|##########| 2/2 [00:00<00:00, 16.30it/s]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/1 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 1/1 [00:00<00:00, 14.12it/s]
#                  all         20         20      0.999          1      0.995      0.929
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#    499/499     1.01G   0.01979  0.006642  0.001816        31       320:   0%|          | 0/2 [00:00<?, ?it/s]
#    499/499     1.01G   0.02072    0.0061  0.001819         5       320:   0%|          | 0/2 [00:00<?, ?it/s]
#    499/499     1.01G   0.02072    0.0061  0.001819         5       320: 100%|##########| 2/2 [00:00<00:00, 15.31it/s]
#    499/499     1.01G   0.02072    0.0061  0.001819         5       320: 100%|##########| 2/2 [00:00<00:00, 15.31it/s]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/1 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 1/1 [00:00<00:00, 14.12it/s]
#                  all         20         20      0.999          1      0.995      0.918
#
# 500 epochs completed in 0.055 hours.
# Optimizer stripped from runs\train\exp17\weights\last.pt, 14.4MB
# Optimizer stripped from runs\train\exp17\weights\best.pt, 14.4MB
#
# Validating runs\train\exp17\weights\best.pt...
# Fusing layers...
# Model summary: 213 layers, 7055974 parameters, 0 gradients, 15.9 GFLOPs
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/1 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 1/1 [00:00<00:00,  9.20it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 1/1 [00:00<00:00,  9.20it/s]
#                  all         20         20      0.999          1      0.995       0.94
#               drowsy         20         10          1          1      0.995      0.982
#                awake         20         10      0.999          1      0.995      0.897
# Results saved to runs\train\exp17

# %% [markdown]
# # 6. Load Custom Model

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp17/weights/last.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to C:\Users\User/.cache\torch\hub\master.zip
# YOLOv5  2022-4-7 torch 1.8.1+cu111 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8192MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7055974 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
img = os.path.join('data', 'images', 'awake.c9a24d48-e1f6-11eb-bbef-5cf3709bbcc6.jpg')

# %%
img = os.path.join('data', 'images', 'a2.jpg')

# %%
results = model(img)

# %%
results.print()
# Out:
# image 1/1: 333x353 1 awake
# Speed: 5.5ms pre-process, 95.3ms inference, 2.0ms NMS per image at shape (1, 3, 608, 640)

# %%
plt.imshow(img)
plt.axis("on")
plt.show()

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = os.path.join('data', 'images', 'a2.jpg')
# img = cv2.imread("1.jpg")
plt.imshow(img)
plt.axis("on")
plt.show()
