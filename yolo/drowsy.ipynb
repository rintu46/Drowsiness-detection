# %%
# !pip install torch==1.8.1+cu111 torchvision==0.9.1+cu111 torchaudio===0.8.1 -f https://download.pytorch.org/whl/lts/1.8/torch_lts.html
# Out:
# Looking in links: https://download.pytorch.org/whl/lts/1.8/torch_lts.html
# Requirement already satisfied: torch==1.8.1+cu111 in d:\yolo\flaskenv\lib\site-packages (1.8.1+cu111)
# Requirement already satisfied: torchvision==0.9.1+cu111 in d:\yolo\flaskenv\lib\site-packages (0.9.1+cu111)
# Requirement already satisfied: torchaudio===0.8.1 in d:\yolo\flaskenv\lib\site-packages (0.8.1)
# Requirement already satisfied: numpy in d:\yolo\flaskenv\lib\site-packages (from torch==1.8.1+cu111) (1.22.3)
# Requirement already satisfied: typing-extensions in d:\yolo\flaskenv\lib\site-packages (from torch==1.8.1+cu111) (4.1.1)
# Requirement already satisfied: pillow>=4.1.1 in d:\yolo\flaskenv\lib\site-packages (from torchvision==0.9.1+cu111) (9.1.0)

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# !cd yolov5 & pip install -r requirements.txt
# Out:
# Requirement already satisfied: matplotlib>=3.2.2 in d:\yolo\flaskenv\lib\site-packages (from -r requirements.txt (line 4)) (3.5.1)
# Requirement already satisfied: numpy>=1.18.5 in d:\yolo\flaskenv\lib\site-packages (from -r requirements.txt (line 5)) (1.22.3)
# Requirement already satisfied: opencv-python>=4.1.2 in d:\yolo\flaskenv\lib\site-packages (from -r requirements.txt (line 6)) (4.5.5.64)
# Requirement already satisfied: Pillow>=7.1.2 in d:\yolo\flaskenv\lib\site-packages (from -r requirements.txt (line 7)) (9.1.0)
# Requirement already satisfied: PyYAML>=5.3.1 in d:\yolo\flaskenv\lib\site-packages (from -r requirements.txt (line 8)) (6.0)
# Requirement already satisfied: requests>=2.23.0 in d:\yolo\flaskenv\lib\site-packages (from -r requirements.txt (line 9)) (2.27.1)
# Requirement already satisfied: scipy>=1.4.1 in d:\yolo\flaskenv\lib\site-packages (from -r requirements.txt (line 10)) (1.8.0)
# Requirement already satisfied: torch>=1.7.0 in d:\yolo\flaskenv\lib\site-packages (from -r requirements.txt (line 11)) (1.8.1+cu111)
# Requirement already satisfied: torchvision>=0.8.1 in d:\yolo\flaskenv\lib\site-packages (from -r requirements.txt (line 12)) (0.9.1+cu111)
# Requirement already satisfied: tqdm>=4.41.0 in d:\yolo\flaskenv\lib\site-packages (from -r requirements.txt (line 13)) (4.64.0)
# Requirement already satisfied: tensorboard>=2.4.1 in d:\yolo\flaskenv\lib\site-packages (from -r requirements.txt (line 16)) (2.8.0)
# Requirement already satisfied: pandas>=1.1.4 in d:\yolo\flaskenv\lib\site-packages (from -r requirements.txt (line 20)) (1.4.2)
# Requirement already satisfied: seaborn>=0.11.0 in d:\yolo\flaskenv\lib\site-packages (from -r requirements.txt (line 21)) (0.11.2)
# Requirement already satisfied: thop in d:\yolo\flaskenv\lib\site-packages (from -r requirements.txt (line 37)) (0.0.31.post2005241907)
# Requirement already satisfied: cycler>=0.10 in d:\yolo\flaskenv\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in d:\yolo\flaskenv\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\yolo\flaskenv\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in d:\yolo\flaskenv\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (4.31.2)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\yolo\flaskenv\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (3.0.7)
# Requirement already satisfied: packaging>=20.0 in d:\yolo\flaskenv\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (21.3)
# Requirement already satisfied: idna<4,>=2.5 in d:\yolo\flaskenv\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\yolo\flaskenv\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in d:\yolo\flaskenv\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\yolo\flaskenv\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (1.26.9)
# Requirement already satisfied: typing-extensions in d:\yolo\flaskenv\lib\site-packages (from torch>=1.7.0->-r requirements.txt (line 11)) (4.1.1)
# Requirement already satisfied: colorama in d:\yolo\flaskenv\lib\site-packages (from tqdm>=4.41.0->-r requirements.txt (line 13)) (0.4.4)
# Requirement already satisfied: werkzeug>=0.11.15 in d:\yolo\flaskenv\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (2.1.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in d:\yolo\flaskenv\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (0.6.1)
# Requirement already satisfied: setuptools>=41.0.0 in d:\yolo\flaskenv\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (61.0.0)
# Requirement already satisfied: wheel>=0.26 in d:\yolo\flaskenv\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (0.37.1)
# Requirement already satisfied: protobuf>=3.6.0 in d:\yolo\flaskenv\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (3.20.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in d:\yolo\flaskenv\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in d:\yolo\flaskenv\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (3.3.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in d:\yolo\flaskenv\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (0.4.6)
# Requirement already satisfied: grpcio>=1.24.3 in d:\yolo\flaskenv\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (1.44.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in d:\yolo\flaskenv\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (2.6.2)
# Requirement already satisfied: absl-py>=0.4 in d:\yolo\flaskenv\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (1.0.0)
# Requirement already satisfied: pytz>=2020.1 in d:\yolo\flaskenv\lib\site-packages (from pandas>=1.1.4->-r requirements.txt (line 20)) (2022.1)
# Requirement already satisfied: six in d:\yolo\flaskenv\lib\site-packages (from absl-py>=0.4->tensorboard>=2.4.1->-r requirements.txt (line 16)) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\yolo\flaskenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 16)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\yolo\flaskenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 16)) (4.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\yolo\flaskenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 16)) (5.0.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\yolo\flaskenv\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.4.1->-r requirements.txt (line 16)) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in d:\yolo\flaskenv\lib\site-packages (from markdown>=2.6.8->tensorboard>=2.4.1->-r requirements.txt (line 16)) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in d:\yolo\flaskenv\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.4.1->-r requirements.txt (line 16)) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\yolo\flaskenv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 16)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\yolo\flaskenv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.4.1->-r requirements.txt (line 16)) (3.2.0)

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in C:\Users\User/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2022-4-6 torch 1.8.1+cu111 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8192MiB)
#
# Fusing layers...
# YOLOv5s_v6 summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): Model(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (3): Conv(
#           (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (4): C3(
#           (cv1): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (5): Conv(
#           (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (6): C3(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (7): Conv(
#           (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (8): C3(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (9): SPPF(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#         )
#         (10): Conv(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (11): Upsample(scale_factor=2.0, mode=nearest)
#         (12): Concat()
#         (13): C3(
#           (cv1): Conv(
#             (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (14): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (15): Upsample(scale_factor=2.0, mode=nearest)
#         (16): Concat()
#         (17): C3(
#           (cv1): Conv(
#             (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (18): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (19): Concat()
#         (20): C3(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (21): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (22): Concat()
#         (23): C3(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (24): Detect(
#           (m): ModuleList(
#             (0): Conv2d(128, 255, kernel_size=(1, 1), stride=(1, 1))
#             (1): Conv2d(256, 255, kernel_size=(1, 1), stride=(1, 1))
#             (2): Conv2d(512, 255, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#       )
#     )
#   )
# )

# %%
img = 'C:/Users/User/c3.jpg'

# %%
results = model(img)
results.print()
# Out:
# image 1/1: 533x800 34 cars, 5 trucks
# Speed: 29.0ms pre-process, 48.9ms inference, 6.0ms NMS per image at shape (1, 3, 448, 640)

# %%
results.render()
# Out:
# [array([[[251, 216, 174],
#          [254, 219, 177],
#          [246, 213, 168],
#          ...,
#          [128, 148, 146],
#          [ 70,  79,  52],
#          [ 64,  71,  29]],
#
#         [[235, 201, 156],
#          [234, 200, 155],
#          [221, 189, 142],
#          ...,
#          [122, 141, 139],
#          [ 85,  91,  65],
#          [ 47,  52,  11]],
#
#         [[253, 219, 171],
#          [245, 213, 164],
#          [212, 180, 131],
#          ...,
#          [136, 155, 153],
#          [ 69,  73,  46],
#          [ 60,  62,  22]],
#
#         ...,
#
#         [[ 61,  69,  80],
#          [ 64,  72,  83],
#          [ 61,  69,  80],
#          ...,
#          [ 47,  52,  56],
#          [ 48,  53,  57],
#          [ 49,  54,  58]],
#
#         [[ 56,  64,  75],
#          [ 72,  80,  91],
#          [ 70,  78,  89],
#          ...,
#          [ 48,  53,  57],
#          [ 48,  53,  57],
#          [ 50,  55,  59]],
#
#         [[ 64,  72,  83],
#          [ 76,  84,  95],
#          [ 63,  71,  82],
#          ...,
#          [ 49,  54,  58],
#          [ 49,  54,  58],
#          [ 50,  55,  59]]], dtype=uint8)]

# %%
import uuid   # Unique identifier
import os
import time

# %%
# !git clone https://github.com/tzutalin/labelImg
# Out:
# fatal: destination path 'labelImg' already exists and is not an empty directory.

# %%
# !pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc
# Out:
# Requirement already satisfied: pyqt5 in d:\yolo\flaskenv\lib\site-packages (5.15.6)
# Requirement already satisfied: lxml in d:\yolo\flaskenv\lib\site-packages (4.8.0)
# Requirement already satisfied: PyQt5-Qt5>=5.15.2 in d:\yolo\flaskenv\lib\site-packages (from pyqt5) (5.15.2)
# Requirement already satisfied: PyQt5-sip<13,>=12.8 in d:\yolo\flaskenv\lib\site-packages (from pyqt5) (12.9.1)

# %%
# !pip install matplotlib_inline
# Out:
# Requirement already satisfied: matplotlib_inline in d:\yolo\flaskenv\lib\site-packages (0.1.3)
# Requirement already satisfied: traitlets in d:\yolo\flaskenv\lib\site-packages (from matplotlib_inline) (5.1.1)

# %%
# !pip install IPython
# Out:
# Requirement already satisfied: IPython in d:\yolo\flaskenv\lib\site-packages (8.2.0)
# Requirement already satisfied: pickleshare in d:\yolo\flaskenv\lib\site-packages (from IPython) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in d:\yolo\flaskenv\lib\site-packages (from IPython) (3.0.29)
# Requirement already satisfied: pygments>=2.4.0 in d:\yolo\flaskenv\lib\site-packages (from IPython) (2.11.2)
# Requirement already satisfied: colorama in d:\yolo\flaskenv\lib\site-packages (from IPython) (0.4.4)
# Requirement already satisfied: decorator in d:\yolo\flaskenv\lib\site-packages (from IPython) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\yolo\flaskenv\lib\site-packages (from IPython) (0.18.1)
# Requirement already satisfied: backcall in d:\yolo\flaskenv\lib\site-packages (from IPython) (0.2.0)
# Requirement already satisfied: matplotlib-inline in d:\yolo\flaskenv\lib\site-packages (from IPython) (0.1.3)
# Requirement already satisfied: traitlets>=5 in d:\yolo\flaskenv\lib\site-packages (from IPython) (5.1.1)
# Requirement already satisfied: stack-data in d:\yolo\flaskenv\lib\site-packages (from IPython) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in d:\yolo\flaskenv\lib\site-packages (from IPython) (61.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in d:\yolo\flaskenv\lib\site-packages (from jedi>=0.16->IPython) (0.8.3)
# Requirement already satisfied: wcwidth in d:\yolo\flaskenv\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython) (0.2.5)
# Requirement already satisfied: executing in d:\yolo\flaskenv\lib\site-packages (from stack-data->IPython) (0.8.3)
# Requirement already satisfied: pure-eval in d:\yolo\flaskenv\lib\site-packages (from stack-data->IPython) (0.2.2)
# Requirement already satisfied: asttokens in d:\yolo\flaskenv\lib\site-packages (from stack-data->IPython) (2.0.5)
# Requirement already satisfied: six in d:\yolo\flaskenv\lib\site-packages (from asttokens->stack-data->IPython) (1.16.0)

# %%
import IPython

# %%
import matplotlib_inline

# %%
# !cd yolov5 && python train.py --epochs 5
# Out:
# Traceback (most recent call last):
#   File "D:\yolo\yolov5\train.py", line 26, in <module>
#     import torch
#   File "D:\yolo\flaskenv\lib\site-packages\torch\__init__.py", line 123, in <module>
#     raise err
# OSError: [WinError 1455] The paging file is too small for this operation to complete. Error loading "D:\yolo\flaskenv\lib\site-packages\torch\lib\caffe2_detectron_ops_gpu.dll" or one of its dependencies.

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 5 --data dataset.yml --weights yolov5s.pt
# Out:
# Traceback (most recent call last):
#   File "D:\yolo\yolov5\train.py", line 26, in <module>
#     import torch
#   File "D:\yolo\flaskenv\lib\site-packages\torch\__init__.py", line 123, in <module>
#     raise err
# OSError: [WinError 1455] The paging file is too small for this operation to complete. Error loading "D:\yolo\flaskenv\lib\site-packages\torch\lib\caffe2_detectron_ops_gpu.dll" or one of its dependencies.

# %%
# !python D:/yolo/yolov5/train.py
# Out:
# train: weights=yolov5\yolov5s.pt, cfg=, data=yolov5\data\coco128.yaml, hyp=yolov5\data\hyps\hyp.scratch-low.yaml, epochs=300, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5\runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github:  YOLOv5 is out of date by 13 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5  v6.1-97-g2da6866 torch 1.8.1+cu111 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8192MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5  runs (RECOMMENDED)
# TensorBoard: Start with 'tensorboard --logdir yolov5\runs\train', view at http://localhost:6006/
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorboard\compat\__init__.py", line 42, in tf
#     from tensorboard.compat import notf  # noqa: F401
# ImportError: cannot import name 'notf' from 'tensorboard.compat' (C:\Users\User\anaconda3\lib\site-packages\tensorboard\compat\__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\yolo\yolov5\train.py", line 662, in <module>
#     main(opt)
#   File "D:\yolo\yolov5\train.py", line 557, in main
#     train(opt.hyp, opt, device, callbacks)
#   File "D:\yolo\yolov5\train.py", line 91, in train
#     loggers = Loggers(save_dir, weights, opt, hyp, LOGGER)  # loggers instance
#   File "D:\yolo\yolov5\utils\loggers\__init__.py", line 76, in __init__
#     self.tb = SummaryWriter(str(s))
#   File "C:\Users\User\anaconda3\lib\site-packages\torch\utils\tensorboard\writer.py", line 220, in __init__
#     self._get_file_writer()
#   File "C:\Users\User\anaconda3\lib\site-packages\torch\utils\tensorboard\writer.py", line 250, in _get_file_writer
#     self.file_writer = FileWriter(self.log_dir, self.max_queue,
#   File "C:\Users\User\anaconda3\lib\site-packages\torch\utils\tensorboard\writer.py", line 60, in __init__
#     self.event_writer = EventFileWriter(
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorboard\summary\writer\event_file_writer.py", line 72, in __init__
#     tf.io.gfile.makedirs(logdir)
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorboard\lazy.py", line 65, in __getattr__
#     return getattr(load_once(self), attr_name)
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorboard\lazy.py", line 97, in wrapper
#     cache[arg] = f(arg)
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorboard\lazy.py", line 50, in load_once
#     module = load_fn()
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorboard\compat\__init__.py", line 45, in tf
#     import tensorflow
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\__init__.py", line 37, in <module>
#     from tensorflow.python.tools import module_util as _module_util
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\__init__.py", line 45, in <module>
#     from tensorflow.python.feature_column import feature_column_lib as feature_column
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\feature_column\feature_column_lib.py", line 18, in <module>
#     from tensorflow.python.feature_column.feature_column import *
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\feature_column\feature_column.py", line 143, in <module>
#     from tensorflow.python.layers import base
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\layers\base.py", line 16, in <module>
#     from tensorflow.python.keras.legacy_tf_layers import base
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\keras\__init__.py", line 25, in <module>
#     from tensorflow.python.keras import models
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\keras\models\__init__.py", line 21, in <module>
#     from tensorflow.python.keras._impl.keras.models import load_model
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\keras\_impl\keras\__init__.py", line 21, in <module>
#     from tensorflow.python.keras._impl.keras import activations
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\keras\_impl\keras\activations.py", line 24, in <module>
#     from tensorflow.python.keras._impl.keras.utils.generic_utils import deserialize_keras_object
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\keras\_impl\keras\utils\__init__.py", line 34, in <module>
#     from tensorflow.python.keras._impl.keras.utils.multi_gpu_utils import multi_gpu_model
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\keras\_impl\keras\utils\multi_gpu_utils.py", line 22, in <module>
#     from tensorflow.python.keras._impl.keras.engine.training import Model
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\keras\_impl\keras\engine\__init__.py", line 21, in <module>
#     from tensorflow.python.keras._impl.keras.engine.base_layer import InputSpec
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\keras\_impl\keras\engine\base_layer.py", line 41, in <module>
#     InputSpec = tf_base_layers.InputSpec
# AttributeError: partially initialized module 'tensorflow.python.layers.base' has no attribute 'InputSpec' (most likely due to a circular import)

# %%
# !python train.py
# Out:
# train: weights=yolov5s.pt, cfg=, data=data\coco128.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=300, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github:  YOLOv5 is out of date by 13 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5  v6.1-97-g2da6866 torch 1.8.1+cu111 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8192MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5  runs (RECOMMENDED)
# TensorBoard: Start with 'tensorboard --logdir runs\train', view at http://localhost:6006/
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorboard\compat\__init__.py", line 42, in tf
#     from tensorboard.compat import notf  # noqa: F401
# ImportError: cannot import name 'notf' from 'tensorboard.compat' (C:\Users\User\anaconda3\lib\site-packages\tensorboard\compat\__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\yolo\yolov5\train.py", line 662, in <module>
#     main(opt)
#   File "D:\yolo\yolov5\train.py", line 557, in main
#     train(opt.hyp, opt, device, callbacks)
#   File "D:\yolo\yolov5\train.py", line 91, in train
#     loggers = Loggers(save_dir, weights, opt, hyp, LOGGER)  # loggers instance
#   File "D:\yolo\yolov5\utils\loggers\__init__.py", line 76, in __init__
#     self.tb = SummaryWriter(str(s))
#   File "C:\Users\User\anaconda3\lib\site-packages\torch\utils\tensorboard\writer.py", line 220, in __init__
#     self._get_file_writer()
#   File "C:\Users\User\anaconda3\lib\site-packages\torch\utils\tensorboard\writer.py", line 250, in _get_file_writer
#     self.file_writer = FileWriter(self.log_dir, self.max_queue,
#   File "C:\Users\User\anaconda3\lib\site-packages\torch\utils\tensorboard\writer.py", line 60, in __init__
#     self.event_writer = EventFileWriter(
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorboard\summary\writer\event_file_writer.py", line 72, in __init__
#     tf.io.gfile.makedirs(logdir)
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorboard\lazy.py", line 65, in __getattr__
#     return getattr(load_once(self), attr_name)
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorboard\lazy.py", line 97, in wrapper
#     cache[arg] = f(arg)
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorboard\lazy.py", line 50, in load_once
#     module = load_fn()
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorboard\compat\__init__.py", line 45, in tf
#     import tensorflow
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\__init__.py", line 37, in <module>
#     from tensorflow.python.tools import module_util as _module_util
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\__init__.py", line 45, in <module>
#     from tensorflow.python.feature_column import feature_column_lib as feature_column
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\feature_column\feature_column_lib.py", line 18, in <module>
#     from tensorflow.python.feature_column.feature_column import *
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\feature_column\feature_column.py", line 143, in <module>
#     from tensorflow.python.layers import base
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\layers\base.py", line 16, in <module>
#     from tensorflow.python.keras.legacy_tf_layers import base
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\keras\__init__.py", line 25, in <module>
#     from tensorflow.python.keras import models
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\keras\models\__init__.py", line 21, in <module>
#     from tensorflow.python.keras._impl.keras.models import load_model
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\keras\_impl\keras\__init__.py", line 21, in <module>
#     from tensorflow.python.keras._impl.keras import activations
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\keras\_impl\keras\activations.py", line 24, in <module>
#     from tensorflow.python.keras._impl.keras.utils.generic_utils import deserialize_keras_object
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\keras\_impl\keras\utils\__init__.py", line 34, in <module>
#     from tensorflow.python.keras._impl.keras.utils.multi_gpu_utils import multi_gpu_model
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\keras\_impl\keras\utils\multi_gpu_utils.py", line 22, in <module>
#     from tensorflow.python.keras._impl.keras.engine.training import Model
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\keras\_impl\keras\engine\__init__.py", line 21, in <module>
#     from tensorflow.python.keras._impl.keras.engine.base_layer import InputSpec
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\keras\_impl\keras\engine\base_layer.py", line 41, in <module>
#     InputSpec = tf_base_layers.InputSpec
# AttributeError: partially initialized module 'tensorflow.python.layers.base' has no attribute 'InputSpec' (most likely due to a circular import)

# %%
# !cd yolov5 && python train.py
# Out:
# train: weights=yolov5s.pt, cfg=, data=data\coco128.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=300, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github:  YOLOv5 is out of date by 13 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# fatal: cannot change to 'C:\Users\User\Desktop\test': No such file or directory
# YOLOv5  2022-4-5 torch 1.8.1+cu111 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8192MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5  runs (RECOMMENDED)
# TensorBoard: Start with 'tensorboard --logdir runs\train', view at http://localhost:6006/
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorboard\compat\__init__.py", line 42, in tf
#     from tensorboard.compat import notf  # noqa: F401
# ImportError: cannot import name 'notf' from 'tensorboard.compat' (C:\Users\User\anaconda3\lib\site-packages\tensorboard\compat\__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\User\Desktop\test 2\yolo\yolov5\train.py", line 662, in <module>
#     main(opt)
#   File "C:\Users\User\Desktop\test 2\yolo\yolov5\train.py", line 557, in main
#     train(opt.hyp, opt, device, callbacks)
#   File "C:\Users\User\Desktop\test 2\yolo\yolov5\train.py", line 91, in train
#     loggers = Loggers(save_dir, weights, opt, hyp, LOGGER)  # loggers instance
#   File "C:\Users\User\Desktop\test 2\yolo\yolov5\utils\loggers\__init__.py", line 76, in __init__
#     self.tb = SummaryWriter(str(s))
#   File "C:\Users\User\anaconda3\lib\site-packages\torch\utils\tensorboard\writer.py", line 220, in __init__
#     self._get_file_writer()
#   File "C:\Users\User\anaconda3\lib\site-packages\torch\utils\tensorboard\writer.py", line 250, in _get_file_writer
#     self.file_writer = FileWriter(self.log_dir, self.max_queue,
#   File "C:\Users\User\anaconda3\lib\site-packages\torch\utils\tensorboard\writer.py", line 60, in __init__
#     self.event_writer = EventFileWriter(
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorboard\summary\writer\event_file_writer.py", line 72, in __init__
#     tf.io.gfile.makedirs(logdir)
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorboard\lazy.py", line 65, in __getattr__
#     return getattr(load_once(self), attr_name)
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorboard\lazy.py", line 97, in wrapper
#     cache[arg] = f(arg)
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorboard\lazy.py", line 50, in load_once
#     module = load_fn()
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorboard\compat\__init__.py", line 45, in tf
#     import tensorflow
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\__init__.py", line 37, in <module>
#     from tensorflow.python.tools import module_util as _module_util
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\__init__.py", line 45, in <module>
#     from tensorflow.python.feature_column import feature_column_lib as feature_column
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\feature_column\feature_column_lib.py", line 18, in <module>
#     from tensorflow.python.feature_column.feature_column import *
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\feature_column\feature_column.py", line 143, in <module>
#     from tensorflow.python.layers import base
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\layers\base.py", line 16, in <module>
#     from tensorflow.python.keras.legacy_tf_layers import base
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\keras\__init__.py", line 25, in <module>
#     from tensorflow.python.keras import models
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\keras\models\__init__.py", line 21, in <module>
#     from tensorflow.python.keras._impl.keras.models import load_model
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\keras\_impl\keras\__init__.py", line 21, in <module>
#     from tensorflow.python.keras._impl.keras import activations
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\keras\_impl\keras\activations.py", line 24, in <module>
#     from tensorflow.python.keras._impl.keras.utils.generic_utils import deserialize_keras_object
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\keras\_impl\keras\utils\__init__.py", line 34, in <module>
#     from tensorflow.python.keras._impl.keras.utils.multi_gpu_utils import multi_gpu_model
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\keras\_impl\keras\utils\multi_gpu_utils.py", line 22, in <module>
#     from tensorflow.python.keras._impl.keras.engine.training import Model
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\keras\_impl\keras\engine\__init__.py", line 21, in <module>
#     from tensorflow.python.keras._impl.keras.engine.base_layer import InputSpec
#   File "C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\keras\_impl\keras\engine\base_layer.py", line 41, in <module>
#     InputSpec = tf_base_layers.InputSpec
# AttributeError: partially initialized module 'tensorflow.python.layers.base' has no attribute 'InputSpec' (most likely due to a circular import)
